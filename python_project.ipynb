# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhashini2711/file/blob/main/python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load the dataset
data = pd.read_csv('maternal_health.csv')

# %% [markdown]
# # New Section

# %%
# Display a portion of the dataset
print("First 20 rows of the dataset:")
print(data.head(20))
# Out:
# First 20 rows of the dataset:
#     Age  SystolicBP  DiastolicBP     BS  BodyTemp  HeartRate  RiskLevel
# 0    25         130           80  15.00      98.0         86  high risk
# 1    35         140           90  13.00      98.0         70  high risk
# 2    29          90           70   8.00     100.0         80  high risk
# 3    30         140           85   7.00      98.0         70  high risk
# 4    35         120           60   6.10      98.0         76   low risk
# 5    23         140           80   7.01      98.0         70  high risk
# 6    23         130           70   7.01      98.0         78   mid risk
# 7    35          85           60  11.00     102.0         86  high risk
# 8    32         120           90   6.90      98.0         70   mid risk
# 9    42         130           80  18.00      98.0         70  high risk
# 10   23          90           60   7.01      98.0         76   low risk
# 11   19         120           80   7.00      98.0         70   mid risk
# ...

# %%
# Drop rows with missing values
#data.dropna(inplace=True)
print("Last 15 rows of the dataset:")
print(data.tail(15))
# Out:
# Last 15 rows of the dataset:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 999    40         120           95  11.0      98.0         80  high risk
# 1000   12          90           60  11.0     102.0         60  high risk
# 1001   60         120           85  15.0      98.0         60  high risk
# 1002   55         140           95  19.0      98.0         77  high risk
# 1003   50         130          100  16.0      98.0         76  high risk
# 1004   13          90           65   9.0     101.0         80  high risk
# 1005   17          90           65   7.7     103.0         67  high risk
# 1006   17          85           60   6.3     102.0         86  high risk
# 1007   40         120           75   7.7      98.0         70  high risk
# 1008   48         120           80  11.0      98.0         88  high risk
# 1009   22         120           60  15.0      98.0         80  high risk
# ...

# %%
#To check the columns of data
data.columns
# Out:
# Index(['Age', 'SystolicBP', 'DiastolicBP', 'BS', 'BodyTemp', 'HeartRate',
#        'RiskLevel'],
#       dtype='object')

# %%
#To check the shape of data
data.shape
# Out:
# (1014, 7)

# %%
#Checking the information of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %%
#Checking the mean,count,std,min,max and percentages
data.describe()
# Out:
#                Age   SystolicBP  DiastolicBP           BS     BodyTemp  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean     29.871795   113.198225    76.460552     8.725986    98.665089
# std      13.474386    18.403913    13.885796     3.293532     1.371384
# min      10.000000    70.000000    49.000000     6.000000    98.000000
# 25%      19.000000   100.000000    65.000000     6.900000    98.000000
# 50%      26.000000   120.000000    80.000000     7.500000    98.000000
# 75%      39.000000   120.000000    90.000000     8.000000    98.000000
# max      70.000000   160.000000   100.000000    19.000000   103.000000
#
#          HeartRate
# count  1014.000000
# mean     74.301775
# std       8.088702
# min       7.000000
# 25%      70.000000
# 50%      76.000000
# 75%      80.000000
# max      90.000000

# %%
 #check for missing values
print("\nMissing values in the dataset:")
print(data.isnull().sum())
# Out:
# Missing values in the dataset:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Use value_counts() to count the occurrences of each risk level
risk_counts = data['RiskLevel'].value_counts()
# Create a bar plot
plt.figure(figsize=(5, 4))
sns.barplot(x=risk_counts.index, y=risk_counts.values, palette='pastel')
plt.title('Distribution of Pregnancy Risk Levels')
plt.xlabel('Risk Level')
plt.ylabel('Count')
plt.show()

# %%
# Bar plot for Age
plt.figure(figsize=(5, 4))
sns.barplot(x='RiskLevel', y='Age', data=data, palette='pastel')
plt.title('Bar Plot of Age by Risk Level')
plt.xlabel('Risk Level')
plt.ylabel('Age')
plt.show()

# %%
# Bar plot for Blood Sugar (BS)
plt.figure(figsize=(5, 4))
sns.barplot(x='RiskLevel', y='BS', data=data, palette='Set1')
plt.title('Bar Plot of Blood Sugar (BS) by Risk Level')
plt.xlabel('Risk Level')
plt.ylabel('Blood Sugar (BS)')
plt.show()

# %%
# Bar plot for Body Temperature (BodyTemp)
plt.figure(figsize=(12, 5))
sns.barplot(x='RiskLevel', y='BodyTemp', data=data, palette='dark')
plt.title('Bar Plot of Body Temperature (BodyTemp) by Risk Level')
plt.xlabel('Risk Level')
plt.ylabel('Body Temperature (BodyTemp)')
plt.show()

# %%
# Bar plot for Systolic Blood Pressure (SystolicBP)
plt.figure(figsize=(12, 5))
sns.barplot(x='RiskLevel', y='SystolicBP', data=data, palette='pastel')
plt.title('Bar Plot of Systolic Blood Pressure (SystolicBP) by Risk Level')
plt.xlabel('Risk Level')
plt.ylabel('Systolic Blood Pressure (SystolicBP)')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Line plot for HeartRate
plt.figure(figsize=(8, 6))
sns.lineplot(x='Age', y='HeartRate', data=data, marker='o', color='lightgreen')
plt.title('Line Plot of Heart Rate (HeartRate) by Age')
plt.xlabel('Age')
plt.ylabel('Heart Rate (bpm)')
plt.show()

# %%
# Box plot for DiastolicBP
plt.figure(figsize=(8, 6))
sns.boxplot(x='DiastolicBP', data=data, color='lightblue')
plt.title('Box Plot of Diastolic Blood Pressure (DiastolicBP)')
plt.xlabel('Diastolic Blood Pressure (mm Hg)')
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'SystolicBP', 'DiastolicBP', 'BS', 'BodyTemp', 'HeartRate',
#        'RiskLevel'],
#       dtype='object')

# %%
#Converting categorical values to numerical data
data['high risk'] = pd.get_dummies(data['RiskLevel'], dtype=int)[['high risk']]
data['mid risk'] = pd.get_dummies(data['RiskLevel'], dtype=int)[['mid risk']]
data['low risk'] = pd.get_dummies(data['RiskLevel'], dtype=int)[['low risk']]
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel  \
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk
#
#    high risk  mid risk  low risk
# 0          1         0         0
# 1          1         0         0
# 2          1         0         0
# 3          1         0         0
# 4          0         0         1

# %%
data.columns
# Out:
# Index(['Age', 'SystolicBP', 'DiastolicBP', 'BS', 'BodyTemp', 'HeartRate',
#        'RiskLevel', 'high risk', 'mid risk', 'low risk'],
#       dtype='object')

# %%
#data.corr()
data.corr(numeric_only=True)
# Out:
#                   Age  SystolicBP  DiastolicBP        BS  BodyTemp  HeartRate  \
# Age          1.000000    0.416045     0.398026  0.473284 -0.255323   0.079798
# SystolicBP   0.416045    1.000000     0.787006  0.425172 -0.286616  -0.023108
# DiastolicBP  0.398026    0.787006     1.000000  0.423824 -0.257538  -0.046151
# BS           0.473284    0.425172     0.423824  1.000000 -0.103493   0.142867
# BodyTemp    -0.255323   -0.286616    -0.257538 -0.103493  1.000000   0.098771
# HeartRate    0.079798   -0.023108    -0.046151  0.142867  0.098771   1.000000
# high risk    0.285251    0.361948     0.375733  0.624716  0.103438   0.182794
# mid risk    -0.078861   -0.001663    -0.113030 -0.198931  0.086407  -0.010987
# low risk    -0.182170   -0.325681    -0.231160 -0.373772 -0.176538  -0.154731
#
#              high risk  mid risk  low risk
# Age           0.285251 -0.078861 -0.182170
# SystolicBP    0.361948 -0.001663 -0.325681
# DiastolicBP   0.375733 -0.113030 -0.231160
# ...

# %%
fig = plt.figure(figsize=(8, 5))
sns.heatmap(data.corr(numeric_only=True), cmap="Purples", annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.histplot(data=data['Age'])
plt.show()

# %%
sns.histplot(data=data['BS'])
plt.show()

# %%
sns.histplot(data=data['HeartRate'],kde=True)
plt.show()

# %%
# Scatter plot for Age vs SystolicBP
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='SystolicBP', hue='RiskLevel', data=data, palette='dark')
plt.title('Scatter Plot of Age vs SystolicBP')
plt.xlabel('Age')
plt.ylabel('SystolicBP')
# Out:
# Text(0, 0.5, 'SystolicBP')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load your dataset into 'data'
# Assuming your dataset is loaded here

# Limit the dataset to 202 rows
data = data.tail(145)

# Splitting dependent and independent data
x = data[['SystolicBP', 'DiastolicBP', 'BS', 'Age']]
y = data['RiskLevel']

# Splitting the dataset into test and train
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# Build a Logistic Regression model
regressor = LogisticRegression(max_iter=1000)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

# Checking the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Classification Report
classification_rep = classification_report(y_test, y_pred)

# Print the classification report
print("Logistic Regression Classification Report:\n", classification_rep)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(5, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Accuracy: 0.8181818181818182
# Logistic Regression Classification Report:
#                precision    recall  f1-score   support
#
#    high risk       0.81      0.72      0.76        18
#     low risk       0.81      0.88      0.85        25
#     mid risk       1.00      1.00      1.00         1
#
#     accuracy                           0.82        44
#    macro avg       0.88      0.87      0.87        44
# weighted avg       0.82      0.82      0.82        44

# %% [markdown]
# This one is the final one
